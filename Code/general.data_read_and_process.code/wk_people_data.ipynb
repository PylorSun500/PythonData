# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
df = pd.read_excel("./assets/people_data.xlsx")
df
# Out:
#       指标  年末总人口(万人)  男性人口(万人)  女性人口(万人)  城镇人口(万人)  乡村人口(万人)
# 0   2004     129988     66976     63012     54283     75705
# 1   2005     130756     67375     63381     56212     74544
# 2   2006     131448     67728     63720     58288     73160
# 3   2007     132129     68048     64081     60633     71496
# 4   2008     132802     68357     64445     62403     70399
# 5   2009     133450     68647     64803     64512     68938
# 6   2010     134091     68748     65343     66978     67113
# 7   2011     134916     69161     65755     69927     64989
# 8   2012     135922     69660     66262     72175     63747
# 9   2013     136726     70063     66663     74502     62224
# 10  2014     137646     70522     67124     76738     60908
# 11  2015     138326     70857     67469     79302     59024
# 12  2016     139232     71307     67925     81924     57308
# 13  2017     140011     71650     68361     84343     55668
# 14  2018     140541     71864     68677     86433     54108
# ...

# %%
yx1 = df['年末总人口(万人)']
yx2 = df['男性人口(万人)']
yx3 = df['女性人口(万人)']
yx4 = df['城镇人口(万人)']
yx5 = df['乡村人口(万人)']
x = df['指标']
plt.plot(x, yx1)
plt.plot(x, yx2)
plt.plot(x, yx3)
plt.plot(x, yx4)
plt.plot(x, yx5)

# %%
df.iloc[:4]
# Out:
#      指标  年末总人口(万人)  男性人口(万人)  女性人口(万人)  城镇人口(万人)  乡村人口(万人)
# 0  2004     129988     66976     63012     54283     75705
# 1  2005     130756     67375     63381     56212     74544
# 2  2006     131448     67728     63720     58288     73160
# 3  2007     132129     68048     64081     60633     71496

# %%
df[['男性人口(万人)', '女性人口(万人)']]
# Out:
#     男性人口(万人)  女性人口(万人)
# 0      66976     63012
# 1      67375     63381
# 2      67728     63720
# 3      68048     64081
# 4      68357     64445
# 5      68647     64803
# 6      68748     65343
# 7      69161     65755
# 8      69660     66262
# 9      70063     66663
# 10     70522     67124
# 11     70857     67469
# 12     71307     67925
# 13     71650     68361
# 14     71864     68677
# 15     72039     68969
# 16     72357     68855
# 17     72311     68949
# 18     72206     68969
# 19     72032     68935
